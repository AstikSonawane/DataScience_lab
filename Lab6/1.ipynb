# %% [markdown]
# ### EDA Processing

# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\HOME\Desktop\DSA\Lab6\data_clean.csv')
#data.describe
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4      67      5    1  2010    67       S
# 1             2   36.0    118.0   8.0      72      5    2  2010    72       C
# 2             3   12.0    149.0  12.6      74      5    3  2010    74      PS
# 3             4   18.0    313.0  11.5      62      5    4  2010    62       S
# 4             5    NaN      NaN  14.3      56      5    5  2010    56       S
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4      67      5    1  2010    67       C
# 154         155   30.0    193.0   6.9      70      9   26  2010    70      PS
# 155         156    NaN    145.0  13.2      77      9   27  2010    77       S
# 156         157   14.0    191.0  14.3      75      9   28  2010    75       S
# 157         158   18.0    131.0   8.0      76      9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.tail()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 153         154   41.0    190.0   7.4      67      5    1  2010    67       C
# 154         155   30.0    193.0   6.9      70      9   26  2010    70      PS
# 155         156    NaN    145.0  13.2      77      9   27  2010    77       S
# 156         157   14.0    191.0  14.3      75      9   28  2010    75       S
# 157         158   18.0    131.0   8.0      76      9   29  2010    76       C

# %%
type(data)
data.shape
# Out:
# (158, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C          int64
# Month           int64
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %% [markdown]
# ### Data Type Conversion

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    int64
#  5   Month       158 non-null    int64
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(6), object(1)
# memory usage: 12.5+ KB

# %%
#checking missing values

data2 = data.iloc[:,1:]
data2
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      67      5    1  2010    67       S
# 1     36.0    118.0   8.0      72      5    2  2010    72       C
# 2     12.0    149.0  12.6      74      5    3  2010    74      PS
# 3     18.0    313.0  11.5      62      5    4  2010    62       S
# 4      NaN      NaN  14.3      56      5    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4      67      5    1  2010    67       C
# 154   30.0    193.0   6.9      70      9   26  2010    70      PS
# 155    NaN    145.0  13.2      77      9   27  2010    77       S
# 156   14.0    191.0  14.3      75      9   28  2010    75       S
# 157   18.0    131.0   8.0      76      9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
# .copy is used so any changes made in this wont be reflected in original data

data3 = data2.copy()
data3
# Out:
#      Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      67      5    1  2010    67       S
# 1     36.0    118.0   8.0      72      5    2  2010    72       C
# 2     12.0    149.0  12.6      74      5    3  2010    74      PS
# 3     18.0    313.0  11.5      62      5    4  2010    62       S
# 4      NaN      NaN  14.3      56      5    5  2010    56       S
# ..     ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4      67      5    1  2010    67       C
# 154   30.0    193.0   6.9      70      9   26  2010    70      PS
# 155    NaN    145.0  13.2      77      9   27  2010    77       S
# 156   14.0    191.0  14.3      75      9   28  2010    75       S
# 157   18.0    131.0   8.0      76      9   29  2010    76       C
#
# [158 rows x 9 columns]

# %%
data3['Month'] = pd.to_numeric(data3['Month'],errors='coerce')
data3['Temp C'] = pd.to_numeric(data3['Temp C'],errors='coerce')
data3['Weather'] = data3['Weather'].astype('category')

# %%
#dropping  temp column
#data4 = data3.drop('Temp',axis=1,inplace=True)
#data4

# %%
#data4.shape()

# %% [markdown]
# #### EDA Processing Starts

# %% [markdown]
# ##### Finding Duplicates

# %%
# Identifying duplicate values from data
data[data.duplicated()].shape
#duplicate
# Out:
# (0, 10)

# %%
#printing duplicated row 
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Ozone, Solar.R, Wind, Temp C, Month, Day, Year, Temp, Weather]
# Index: []

# %%
#dropping duplicated rows

data_cleaned1 = data.drop_duplicates()
data_cleaned1.shape
# Out:
# (158, 10)

# %% [markdown]
# ### Drop columns

# %%
# dropping duplicated temp column no need to do since already done hence copying
#data_cleaned2 = data_cleaned1.drop('Temp C',axis = 1,inplace=True) 
data_cleaned2 = data_cleaned1.copy()
data_cleaned2
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4      67      5    1  2010    67       S
# 1             2   36.0    118.0   8.0      72      5    2  2010    72       C
# 2             3   12.0    149.0  12.6      74      5    3  2010    74      PS
# 3             4   18.0    313.0  11.5      62      5    4  2010    62       S
# 4             5    NaN      NaN  14.3      56      5    5  2010    56       S
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4      67      5    1  2010    67       C
# 154         155   30.0    193.0   6.9      70      9   26  2010    70      PS
# 155         156    NaN    145.0  13.2      77      9   27  2010    77       S
# 156         157   14.0    191.0  14.3      75      9   28  2010    75       S
# 157         158   18.0    131.0   8.0      76      9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# ### Rename column

# %%
data_cleaned3 = data_cleaned2.rename({'Solar.R':'Solar'},axis=1)
data_cleaned3
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4      67      5    1  2010    67       S
# 1             2   36.0  118.0   8.0      72      5    2  2010    72       C
# 2             3   12.0  149.0  12.6      74      5    3  2010    74      PS
# 3             4   18.0  313.0  11.5      62      5    4  2010    62       S
# 4             5    NaN    NaN  14.3      56      5    5  2010    56       S
# ..          ...    ...    ...   ...     ...    ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4      67      5    1  2010    67       C
# 154         155   30.0  193.0   6.9      70      9   26  2010    70      PS
# 155         156    NaN  145.0  13.2      77      9   27  2010    77       S
# 156         157   14.0  191.0  14.3      75      9   28  2010    75       S
# 157         158   18.0  131.0   8.0      76      9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# ### Outlier Detection

# %%
#histogram of ozone
data_cleaned3['Ozone'].hist()
# Out:
# <Axes: >
# 2024-02-29 22:52:51,575 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,576 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,577 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,578 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,579 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,579 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,580 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,581 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,582 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,583 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,586 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %%
#boxplot
data_cleaned3.boxplot(column=['Ozone'])
# Out:
# <Axes: >
# 2024-02-29 22:52:51,726 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,727 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,728 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,735 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,737 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,738 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,739 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,739 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,740 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,741 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,742 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %%
#Descriptive stat

data_cleaned3['Ozone'].describe()
# Out:
# count    120.000000
# mean      41.583333
# std       32.620709
# min        1.000000
# 25%       18.000000
# 50%       30.500000
# 75%       61.500000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
data_cleaned3
# Out:
#      Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp Weather
# 0             1   41.0  190.0   7.4      67      5    1  2010    67       S
# 1             2   36.0  118.0   8.0      72      5    2  2010    72       C
# 2             3   12.0  149.0  12.6      74      5    3  2010    74      PS
# 3             4   18.0  313.0  11.5      62      5    4  2010    62       S
# 4             5    NaN    NaN  14.3      56      5    5  2010    56       S
# ..          ...    ...    ...   ...     ...    ...  ...   ...   ...     ...
# 153         154   41.0  190.0   7.4      67      5    1  2010    67       C
# 154         155   30.0  193.0   6.9      70      9   26  2010    70      PS
# 155         156    NaN  145.0  13.2      77      9   27  2010    77       S
# 156         157   14.0  191.0  14.3      75      9   28  2010    75       S
# 157         158   18.0  131.0   8.0      76      9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
#bar plot
data['Weather'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Weather'>
# 2024-02-29 22:52:51,870 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,871 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,872 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,873 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,875 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,876 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,877 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,878 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,879 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,885 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:51,886 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %% [markdown]
# ### Missing Values and Imputation

# %%
import seaborn as sns

cols = data_cleaned3.columns
colours = ['#000099', '#ffff00']
sns.heatmap(data_cleaned3[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# 2024-02-29 22:52:52,015 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,016 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,017 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,019 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,019 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,020 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,021 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,022 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,023 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,024 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,025 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:52,026 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %%
data_cleaned3[data_cleaned3.isnull().any(axis=1)].head()
# Out:
#     Unnamed: 0  Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp Weather
# 4            5    NaN    NaN  14.3      56      5    5  2010    56       S
# 5            6   28.0    NaN  14.9      66      5    6  2010    66       C
# 9           10    NaN  194.0   8.6      69      5   10  2010    69       S
# 10          11    7.0    NaN   6.9      66      5   11  2010    74       C
# 24          25    NaN   66.0  16.6      57      5   25  2010    57      PS

# %%
data_cleaned3.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar          7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
#Mean Imputation

mean = data_cleaned3['Ozone'].mean()
mean
# Out:
# 41.583333333333336

# %%
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(mean)
data_cleaned3
# Out:
#      Unnamed: 0      Ozone  Solar  Wind  Temp C  Month  Day  Year  Temp  \
# 0             1  41.000000  190.0   7.4      67      5    1  2010    67
# 1             2  36.000000  118.0   8.0      72      5    2  2010    72
# 2             3  12.000000  149.0  12.6      74      5    3  2010    74
# 3             4  18.000000  313.0  11.5      62      5    4  2010    62
# 4             5  41.583333    NaN  14.3      56      5    5  2010    56
# ..          ...        ...    ...   ...     ...    ...  ...   ...   ...
# 153         154  41.000000  190.0   7.4      67      5    1  2010    67
# 154         155  30.000000  193.0   6.9      70      9   26  2010    70
# 155         156  41.583333  145.0  13.2      77      9   27  2010    77
# 156         157  14.000000  191.0  14.3      75      9   28  2010    75
# 157         158  18.000000  131.0   8.0      76      9   29  2010    76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# ...

# %%
#Mean Imputation of solar

mean = data_cleaned3['Solar'].mean()
data_cleaned3['Solar'] = data_cleaned3['Solar'].fillna(mean)
mean
# Out:
# 185.40397350993376

# %%
#Mean Imputation of ozone

mean = data_cleaned3['Ozone'].mean()
data_cleaned3['Ozone'] = data_cleaned3['Ozone'].fillna(mean)
mean
# Out:
# 41.58333333333334

# %%
#Mean Imputation of Month

mean = data_cleaned3['Month'].mean()
data_cleaned3['Month'] = data_cleaned3['Month'].fillna(mean)
#mean

# %%
#Mean Imputation of Temp 

mean = data_cleaned3['Temp'].mean()
data_cleaned3['Temp'] = data_cleaned3['Temp'].fillna(mean)
mean
#data_cleaned3.info()
# Out:
# 77.72784810126582

# %%
# Imputation of Weather
obj_columns = data_cleaned3[['Weather']]
obj_columns.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
obj_columns
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 1 columns]

# %%
#missing value imputation for categorical value
obj_columns = obj_columns.fillna(obj_columns.mode().iloc[0])

# %%
obj_columns.mode()
# Out:
#   Weather
# 0       S

# %%
obj_columns.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
data_cleaned3.shape
# Out:
# (158, 10)

# %%
obj_columns.shape
# Out:
# (158, 1)

# %%
#join data set with imputed value

data_cleaned4 = pd.concat([data_cleaned3,obj_columns],axis=1)

# %%
data_cleaned4
# Out:
#      Unnamed: 0      Ozone       Solar  Wind  Temp C  Month  Day  Year  Temp  \
# 0             1  41.000000  190.000000   7.4      67      5    1  2010    67
# 1             2  36.000000  118.000000   8.0      72      5    2  2010    72
# 2             3  12.000000  149.000000  12.6      74      5    3  2010    74
# 3             4  18.000000  313.000000  11.5      62      5    4  2010    62
# 4             5  41.583333  185.403974  14.3      56      5    5  2010    56
# ..          ...        ...         ...   ...     ...    ...  ...   ...   ...
# 153         154  41.000000  190.000000   7.4      67      5    1  2010    67
# 154         155  30.000000  193.000000   6.9      70      9   26  2010    70
# 155         156  41.583333  145.000000  13.2      77      9   27  2010    77
# 156         157  14.000000  191.000000  14.3      75      9   28  2010    75
# 157         158  18.000000  131.000000   8.0      76      9   29  2010    76
#
#     Weather Weather
# 0         S       S
# ...

# %% [markdown]
# ### Scatter Plot and correlation analysis

# %%
sns.pairplot(data_cleaned3)
# Out:
# 2024-02-29 22:52:53,438 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,439 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,440 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,441 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,442 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,443 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,443 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,446 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,564 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,678 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,791 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-02-29 22:52:53,906 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %%
# Select only numeric columns
numeric_data = data_cleaned3.select_dtypes(include=np.number)

#compute correlation matrix
correlation_matrix = numeric_data.corr()

#print correlation matrix
correlation_matrix
# Out:
#             Unnamed: 0     Ozone     Solar      Wind    Temp C     Month  \
# Unnamed: 0    1.000000  0.111910 -0.106199 -0.158309  0.344139  0.950120
# Ozone         0.111910  1.000000  0.303166 -0.523806  0.610174  0.126177
# Solar        -0.106199  0.303166  1.000000 -0.055092  0.259318 -0.079196
# Wind         -0.158309 -0.523806 -0.055092  1.000000 -0.434580 -0.157623
# Temp C        0.344139  0.610174  0.259318 -0.434580  1.000000  0.408796
# Month         0.950120  0.126177 -0.079196 -0.157623  0.408796  1.000000
# Day           0.216219 -0.030241 -0.149606  0.040151 -0.120976  0.052646
# Year               NaN       NaN       NaN       NaN       NaN       NaN
# Temp          0.337537  0.606275  0.260473 -0.441247  0.997717  0.402942
#
#                  Day  Year      Temp
# Unnamed: 0  0.216219   NaN  0.337537
# Ozone      -0.030241   NaN  0.606275
# Solar      -0.149606   NaN  0.260473
# Wind        0.040151   NaN -0.441247
# Temp C     -0.120976   NaN  0.997717
# ...

# %% [markdown]
# ### Transformations

# %% [markdown]
# ##### Dummy Variable

# %%
#creating dummy for weather

data_cleaned4 = pd.get_dummies(data,columns=['Weather'])
data_cleaned4
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp C  Month  Day  Year  Temp  \
# 0             1   41.0    190.0   7.4      67      5    1  2010    67
# 1             2   36.0    118.0   8.0      72      5    2  2010    72
# 2             3   12.0    149.0  12.6      74      5    3  2010    74
# 3             4   18.0    313.0  11.5      62      5    4  2010    62
# 4             5    NaN      NaN  14.3      56      5    5  2010    56
# ..          ...    ...      ...   ...     ...    ...  ...   ...   ...
# 153         154   41.0    190.0   7.4      67      5    1  2010    67
# 154         155   30.0    193.0   6.9      70      9   26  2010    70
# 155         156    NaN    145.0  13.2      77      9   27  2010    77
# 156         157   14.0    191.0  14.3      75      9   28  2010    75
# 157         158   18.0    131.0   8.0      76      9   29  2010    76
#
#      Weather_C  Weather_PS  Weather_S
# 0        False       False       True
# 1         True       False      False
# ...

# %%
data_cleaned4 = data_cleaned4.dropna()

# %% [markdown]
# ### Normalization of data

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_cleaned4.values
# Out:
# array([[1, 41.0, 190.0, ..., False, False, True],
#        [2, 36.0, 118.0, ..., True, False, False],
#        [3, 12.0, 149.0, ..., False, True, False],
#        ...,
#        [155, 30.0, 193.0, ..., False, True, False],
#        [157, 14.0, 191.0, ..., False, False, True],
#        [158, 18.0, 131.0, ..., True, False, False]], dtype=object)

# %%
array = data_cleaned3.values
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array[:,0:5])
#summarize
set_printoptions(precision = 2)
print(rescaledX[0:5,:])
# Out:
# [[0.   0.24 0.56 0.3  0.27]
#  [0.01 0.21 0.34 0.33 0.39]
#  [0.01 0.07 0.43 0.57 0.44]
#  [0.02 0.1  0.94 0.52 0.15]
#  [0.03 0.24 0.55 0.66 0.  ]]

# %%
#standardize data (0mean,1sd)
from sklearn.preprocessing import StandardScaler

# %%
array = data_cleaned4.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

#summarize
set_printoptions(precision = 2)
print(rescaledX[0:5,:])
#data_cleaned4
# Out:
# [[-1.82 -0.02  0.06 -0.71 -1.13 -1.51 -1.71  0.   -1.13 -0.65 -0.68  1.29]
#  [-1.8  -0.17 -0.74 -0.54 -0.59 -1.51 -1.6   0.   -0.59  1.54 -0.68 -0.77]
#  [-1.78 -0.9  -0.4   0.76 -0.38 -1.51 -1.49  0.   -0.38 -0.65  1.48 -0.77]
#  [-1.76 -0.72  1.44  0.45 -1.66 -1.51 -1.37  0.   -1.66 -0.65 -0.68  1.29]
#  [-1.69 -0.57  1.28 -0.37 -1.34 -1.51 -1.03  0.   -1.34 -0.65  1.48 -0.77]]

# %% [markdown]
# ## Speed up the EDA process

# %%
#install dtale

import dtale 
dtale.show(data)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-C3OEI493:40000/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
